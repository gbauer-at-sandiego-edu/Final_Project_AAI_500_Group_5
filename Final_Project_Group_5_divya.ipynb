# %%
#1. Display Red and White Wine Datasets

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import math
import scipy.stats
from sklearn.linear_model import LinearRegression

Display Red Wine Dataset
file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-red.xlsx'
Red_wine=pd.read_excel(file_path)
display(Red_wine)

Display White Wine Dataset
file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-white.xlsx'
White_wine=pd.read_excel(file_path)
display(White_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#3. Provide Descriptive Statistics of the variables for Red wine dataset
descriptive_statistics=Red_wine.describe()
print(descriptive_statistics)

#Provide Descriptive Statistics of the variables for White wine dataset
descriptive_statistics=White_wine.describe()
print(descriptive_statistics)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#2. Draw a Histrogram for Red and White wine dataset of all the variables 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import math
import scipy.stats
from sklearn.linear_model import LinearRegression


#RED WINE: read and display datafile using pandas library function 
file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-red.xlsx'
Red_wine=pd.read_excel(file_path)
def continuous_plots(df, columns, num_cols):
    n_plots = len(columns)
    n_cols = num_cols
    n_rows = int(math.ceil(n_plots/n_cols))
    gs = gridspec.GridSpec(n_rows, n_cols)
    fig = plt.figure(figsize=(24,8))
    for i in range(n_plots):
        ax = fig.add_subplot(gs[i])
        df[columns[i]].hist(ax=ax, grid=False)
        ax.set_xlabel(columns[i])
    fig.tight_layout()
    fig.supylabel('Count')
    plt.title ("Red Wine Distributions")                                 
    plt.show()
columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
continuous_plots(Red_wine, columns, num_cols=3)

#WHITE WINE: read and display datafile using pandas library function 
file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-white.xlsx'
White_wine=pd.read_excel(file_path)
def continuous_plots(df, columns, num_cols):
    n_plots = len(columns)
    n_cols = num_cols
    n_rows = int(math.ceil(n_plots/n_cols))
    gs = gridspec.GridSpec(n_rows, n_cols)
    fig = plt.figure(figsize=(24,8))
    for i in range(n_plots):
        ax = fig.add_subplot(gs[i])
        df[columns[i]].hist(ax=ax, grid=False)
        ax.set_xlabel(columns[i])
    fig.tight_layout()
    fig.supylabel('Count')
    plt.title ("White Wine Distributions")                                 
    plt.show()
columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
continuous_plots(White_wine, columns, num_cols=3)

# %%
#4. Box Plot of the variables for Red Wine dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import math
import scipy.stats
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-red.xlsx'
Red_wine=pd.read_excel(file_path)
variables = ['fixed acidity', 'volatile acidity', 'citric acid']
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
for ax, variable in zip(axes, variables):
    sns.boxplot(data=Red_wine[variable], ax=ax, orient='h')
    ax.set_title(f'Box plot of {variable.capitalize()}') 
    ax.set_xlabel(variable.capitalize())
    ax.set_ylabel('Values')
plt.tight_layout()
plt.show()

#Box Plot of the variables for White Wine dataset
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-white.xlsx'
White_wine=pd.read_excel(file_path)
variables = ['fixed acidity', 'volatile acidity', 'citric acid']
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
for ax, variable in zip(axes, variables):
    sns.boxplot(data=White_wine[variable], ax=ax, orient='h')
    ax.set_title(f'Box plot of {variable.capitalize()}') 
    ax.set_xlabel(variable.capitalize())
    ax.set_ylabel('Values')
plt.tight_layout()
plt.show()

# %%
#5. Constructing a Wald 95% confidence interval for Red Wine dataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import math
import scipy.stats
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

file_path=r'C:\Users\DeeHa\Documents\CAPSTONE project\winequality-red.xlsx'
Red_wine=pd.read_excel(file_path)
Red_acidity =Red_wine['fixed acidity']
mean_acidity_R=sum(Red_acidity)/len(Red_acidity)
std_deviation = np.std(Red_acidity,ddof=1)
t_value = stats.t.ppf(0.975,(total_rows-1))
std_error = std_deviation/np.sqrt(total_rows)
low_bound = mean_acidity_R - t_value*std_error
high_bound = mean_acidity_R + t_value*std_error
print("Low Bound:", low_bound)
print("High Bound:", high_bound)
plt.hist(Red_acidity, bins=20, alpha=0.6, color='b', label='Acidity Range')
plt.axvline(mean_acidity_R, color='r', linestyle='dashed', linewidth=2, label=f'Mean Acidity = {mean_acidity_R:.2f}')
plt.axvline(low_bound, color='g', linestyle='dotted', linewidth=2, label=f'95% CI Lower = {low_bound:.2f}')
plt.axvline(high_bound, color='g', linestyle='dotted', linewidth=2, label=f'95% CI Upper = {high_bound:.2f}')
plt.xlabel('Acidity')
plt.ylabel('Range')
plt.title('Wald Confidence Intervals for Red Wine Acidity')
plt.legend()
plt.show()

#5. Constructing a Wald 95% confidence interval for White Wine dataset
White_acidity=White_wine['fixed acidity']
mean_acidity_W=sum(White_acidity)/len(White_acidity)
std_deviation_W = np.std(White_acidity,ddof=1)
t_value = stats.t.ppf(0.975,(total_rows-1))
std_error_W = std_deviation_W/np.sqrt(total_rows)
low_bound = mean_acidity_W - t_value*std_error_W
high_bound = mean_acidity_W + t_value*std_error_W
print("Low Bound:", low_bound)
print("High Bound:", high_bound)
plt.hist(White_acidity, bins=20, alpha=0.6, color='b', label='Acidity Range')
plt.axvline(mean_acidity_W, color='r', linestyle='dashed', linewidth=2, label=f'Mean Acidity = {mean_acidity_W:.2f}')
plt.axvline(low_bound, color='g', linestyle='dotted', linewidth=2, label=f'95% CI Lower = {low_bound:.2f}')
plt.axvline(high_bound, color='g', linestyle='dotted', linewidth=2, label=f'95% CI Upper = {high_bound:.2f}')
plt.xlabel('Acidity')
plt.ylabel('Range')
plt.title('Wald Confidence Intervals for White Wine Acidity')
plt.legend()
plt.show()
# Out:
# Low Bound: 8.270865465597979
# High Bound: 8.36840908099364
# Low Bound: 6.831149126159847
# High Bound: 6.878426210712346

# %%
#7.Significance test for Red Wine Dataset

#Extract rows for each group 
Y_quality5=Red_wine[Red_wine['quality'] == 5]
Y_quality7=Red_wine[Red_wine['quality'] == 7]
Y_quality8=Red_wine[Red_wine['quality'] == 8]

#Total no of rows in a dataset
n=Red_wine.shape[0]
n_quality5=Y_quality5.shape[0]
n_quality7=Y_quality7.shape[0]
n_quality8=Y_quality8.shape[0]

#calculate Descriptiive statistics for each group 
mean_quality5 = sum(Y_quality5['fixed acidity'])/n_quality5
mean_quality7 = sum(Y_quality7['fixed acidity'])/n_quality7
mean_quality8= sum(Y_quality8['fixed acidity'])/n_quality8
print(f"Mean acidity for Quality 5 wines: {mean_quality5}")
print(f"Mean acidity for Quality 7 wines: {mean_quality7}")
print(f"Mean acidity for Quality 8 wines: {mean_quality8}")

std_deviation_quality5 = np.std(Y_quality5['fixed acidity'],ddof=1)
std_deviation_quality7 = np.std(Y_quality7['fixed acidity'],ddof=1)
std_deviation_quality8 = np.std(Y_quality8['fixed acidity'],ddof=1)

# Calculate the t-statistic and p-value for each pair og groups
t_statistic_57 = (mean_quality5 - mean_quality7) / np.sqrt((std_deviation_quality5**2 / n_quality5) + (std_deviation_quality7**2 / n_quality7))
t_statistic_78 = (mean_quality7 - mean_quality8) / np.sqrt((std_deviation_quality7**2 / n_quality7) + (std_deviation_quality8**2 / n_quality8))
t_statistic_85 = (mean_quality8 - mean_quality5) / np.sqrt((std_deviation_quality8**2 / n_quality8) + (std_deviation_quality5**2 / n_quality5))

# Calculate the p-value
p_value_57 = 2 * stats.t.sf(np.abs(t_statistic_57), df=n_quality5 + n_quality7 - 2)
p_value_78 = 2 * stats.t.sf(np.abs(t_statistic_78), df=n_quality7 + n_quality8 - 2)
p_value_85 = 2 * stats.t.sf(np.abs(t_statistic_85), df=n_quality8 + n_quality5 - 2)

print(f"T-statistic for quality 5 and 7: {t_statistic_57}")
print(f"P-value for quality 5 and 7: {p_value_57}")

print(f"T-statistic for quality 7 and 8: {t_statistic_78}")
print(f"P-value for quality 7 and 8: {p_value_78}")

print(f"T-statistic for quality 8 and 5: {t_statistic_85}")
print(f"P-value for quality 8 and 5: {p_value_85}")

#6.Significance test for White Wine Dataset

#Extract rows for each group 
Y_quality5=White_wine[White_wine['quality'] == 5]
Y_quality7=White_wine[White_wine['quality'] == 7]
Y_quality8=White_wine[White_wine['quality'] == 8]

#Total no of rows in a dataset
n=Red_wine.shape[0]
n_quality5=Y_quality5.shape[0]
n_quality7=Y_quality7.shape[0]
n_quality8=Y_quality8.shape[0]

#calculate Descriptiive statistics for each group 
mean_quality5 = sum(Y_quality5['fixed acidity'])/n_quality5
mean_quality7 = sum(Y_quality7['fixed acidity'])/n_quality7
mean_quality8= sum(Y_quality8['fixed acidity'])/n_quality8
print(f"Mean acidity for Quality 5 wines: {mean_quality5}")
print(f"Mean acidity for Quality 7 wines: {mean_quality7}")
print(f"Mean acidity for Quality 8 wines: {mean_quality8}")

std_deviation_quality5 = np.std(Y_quality5['fixed acidity'],ddof=1)
std_deviation_quality7 = np.std(Y_quality7['fixed acidity'],ddof=1)
std_deviation_quality8 = np.std(Y_quality8['fixed acidity'],ddof=1)

# Calculate the t-statistic and p-value for each pair og groups
t_statistic_57 = (mean_quality5 - mean_quality7) / np.sqrt((std_deviation_quality5**2 / n_quality5) + (std_deviation_quality7**2 / n_quality7))
t_statistic_78 = (mean_quality7 - mean_quality8) / np.sqrt((std_deviation_quality7**2 / n_quality7) + (std_deviation_quality8**2 / n_quality8))
t_statistic_85 = (mean_quality8 - mean_quality5) / np.sqrt((std_deviation_quality8**2 / n_quality8) + (std_deviation_quality5**2 / n_quality5))

# Calculate the p-value
p_value_57 = 2 * stats.t.sf(np.abs(t_statistic_57), df=n_quality5 + n_quality7 - 2)
p_value_78 = 2 * stats.t.sf(np.abs(t_statistic_78), df=n_quality7 + n_quality8 - 2)
p_value_85 = 2 * stats.t.sf(np.abs(t_statistic_85), df=n_quality8 + n_quality5 - 2)

print(f"T-statistic for quality 5 and 7: {t_statistic_57}")
print(f"P-value for quality 5 and 7: {p_value_57}")

print(f"T-statistic for quality 7 and 8: {t_statistic_78}")
print(f"P-value for quality 7 and 8: {p_value_78}")

print(f"T-statistic for quality 8 and 5: {t_statistic_85}")
print(f"P-value for quality 8 and 5: {p_value_85}")
# Out:
# Mean acidity for Quality 5 wines: 8.167254038179149
# Mean acidity for Quality 7 wines: 8.872361809045225
# Mean acidity for Quality 8 wines: 8.566666666666666
# T-statistic for quality 5 and 7: -4.595554047570724
# P-value for quality 5 and 7: 4.9481204945516464e-06
# T-statistic for quality 7 and 8: 0.5887932123842451
# P-value for quality 7 and 8: 0.5566180817273532
# T-statistic for quality 8 and 5: 0.7937617985688122
# P-value for quality 8 and 5: 0.42760425957643533
# Mean acidity for Quality 5 wines: 6.933973919011668
# Mean acidity for Quality 7 wines: 6.73471590909091
# Mean acidity for Quality 8 wines: 6.6571428571428575
# T-statistic for quality 5 and 7: 5.923943180851055
# P-value for quality 5 and 7: 3.6079382169185415e-09
# T-statistic for quality 7 and 8: 1.1583249872251868
# P-value for quality 7 and 8: 0.2469940750513391
# T-statistic for quality 8 and 5: -4.212555024087274
# P-value for quality 8 and 5: 2.6631084280481546e-05
